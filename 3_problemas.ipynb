# %% [markdown]
# # Problemas

# %% [markdown]
# Problemas propuestos a resolver para la clase. En este documento resolveré algunos y luego pasaré los demás.

# %% [markdown]
# ## 7. Flujo de agua a través de capilares

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A partir de la _ley de Poiseuille_ des
